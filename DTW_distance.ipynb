# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pickle

var = pickle.load(open("dist_set.p", "rb" ))
dist_array, pid, tremor_all, wfs_all = var

# %%
fig = plt.figure(figsize=[10,10])
plt.imshow(dist_array);
plt.colorbar();
dx = plt.xlim()
plt.scatter(np.linspace(dx[0],dx[1],len(tremor_all,)),np.zeros(len(tremor_all,))-3,
            c=tremor_all, alpha=.5, cmap='inferno', marker='o');
plt.scatter(np.zeros(len(tremor_all,))-3,np.linspace(dx[0],dx[1],len(tremor_all,)),
            c=tremor_all, alpha=.5, cmap='inferno', marker='o');

#plt.xlim(dx)

# %%
fig = plt.figure(figsize=[10,10])
plt.imshow(dist_array);
plt.colorbar();
dx = plt.xlim()
plt.scatter(np.linspace(dx[0],dx[1],len(pid,)),np.zeros(len(pid,))-3,
            c=pid, alpha=.5, cmap='Set2', marker='o');
plt.scatter(np.zeros(len(pid,))-3, np.linspace(dx[0],dx[1],len(pid)), 
            c=pid, alpha=.5, cmap='Set2', marker='o');

#plt.xlim(dx)

# %%
plt.hist(pid);
plt.xlabel('(masked) patient ID')
# Out:
# Text(0.5, 0, '(masked) patient ID')

# %%
plt.hist(tremor_all);
plt.xlabel('tremor rating')
# Out:
# Text(0.5, 0, 'tremor rating')
